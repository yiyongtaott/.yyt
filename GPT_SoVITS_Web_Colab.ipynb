# %% [markdown]
# <a href="https://colab.research.google.com/github/yiyongtaott/.yyt/blob/main/GPT_SoVITS_Web_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 基于[RVC-Boss/GPT-SoVITS/colab_webui.ipynb](https://github.com/RVC-Boss/GPT-SoVITS/blob/main/colab_webui.ipynb)进行了一些完善，便于结合Google Drive更快的进行数据集的上传和训练模型的下载
#
# [官方colab教程链接](https://www.yuque.com/baicaigongchang1145haoyuangong/ib3g1e/zqbopihzr6eqoyl8)
#
# Based on [RVC-Boss/GPT-SoVITS/colab_webui.ipynb](https://github.com/RVC-Boss/GPT-SoVITS/blob/main/colab_webui.ipynb), some improvements have been made to facilitate faster integration with Google Drive Upload the data set and download the training model

# %% [markdown]
# ---
# #### Part0:前置准备 Preparation
# ---

# %%
#@title 查看CPU/GPU配置

#@markdown Check CPU/GPU configuration
# !lscpu | grep -E 'Architecture|Model name|Core\(s\)|CPU\(s\):'
# !nvidia-smi
# Out:
# Architecture:                            x86_64
# CPU(s):                                  2
# Model name:                              Intel(R) Xeon(R) CPU @ 2.20GHz
# Core(s) per socket:                      1
# NUMA node0 CPU(s):                       0,1
# /bin/bash: line 1: nvidia-smi: command not found

# %%
#@title  挂载Google云端硬盘 / Mount Google drive
#@markdown 加载Google云端硬盘（更快地上传数据集文件）

#@markdown Mount Google drive for faster data upload
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title 创建Google Drive数据集上传文件夹
#@markdown Create Google Drive dataset upload folder
rolename = input("请输入本次要训练的角色名称 Please enter the role name for this training：")
# !mkdir -p /content/drive/MyDrive/GPT_SoVITS/raw_audio/{rolename}/
print("目录创建成功 Directory created successfully!")
print("请将本次的数据集上传到 Please upload the data set for this training to:")
print("Google Drive：https://drive.google.com/drive/my-drive")
print("/GPT_SoVITS/raw_audio/%s " % rolename)
print("Web UI音频数据集对应目录 Directory of Web UI audio data set:")
print("---------------------------------------------------------")
print("/content/drive/MyDrive/GPT_SoVITS/raw_audio/%s " % rolename)
print("---------------------------------------------------------")
# Out:
# 请输入本次要训练的角色名称 Please enter the role name for this training：FlandreTiamat
# 目录创建成功 Directory created successfully!
# 请将本次的数据集上传到 Please upload the data set for this training to:
# Google Drive：https://drive.google.com/drive/my-drive
# /GPT_SoVITS/raw_audio/FlandreTiamat
# Web UI音频数据集对应目录 Directory of Web UI audio data set:
# ---------------------------------------------------------
# /content/drive/MyDrive/GPT_SoVITS/raw_audio/FlandreTiamat
# ---------------------------------------------------------

# %% [markdown]
# ---
#
# #### Part1:环境安装配置 Environment installation configuration
# ---

# %%
#@title STEP:1.1 环境配置下载安装 (≈15min)
# !pip install -q condacolab
#@markdown Setting up condacolab and installing packages (≈15min)
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/miniconda/Miniconda3-py39_23.11.0-2-Linux-x86_64.sh")
# %cd -q /content
# !git clone https://github.com/RVC-Boss/GPT-SoVITS
# !conda install -y -q -c pytorch -c nvidia cudatoolkit
# %cd -q /content/GPT-SoVITS
# !conda install -y -q -c conda-forge gcc gxx ffmpeg cmake -c pytorch -c nvidia
# !/usr/local/bin/pip install -r requirements.txt --target=/content/drive/MyDrive/colab_env/gpt_sovits_lib
# Out:
# ✨🍰✨ Everything looks OK!
# fatal: destination path 'GPT-SoVITS' already exists and is not an empty directory.
# Error while loading conda entry point: conda-libmamba-solver (libarchive.so.20: cannot open shared object file: No such file or directory)
# /usr/local/lib/python3.9/site-packages/conda/base/context.py:201: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
#
# CondaValueError: You have chosen a non-default solver backend (libmamba) but it was not recognized. Choose one of: classic
#
# Error while loading conda entry point: conda-libmamba-solver (libarchive.so.20: cannot open shared object file: No such file or directory)
# /usr/local/lib/python3.9/site-packages/conda/base/context.py:201: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
#
# CondaValueError: You have chosen a non-default solver backend (libmamba) but it was not recognized. Choose one of: classic
#
# Ignoring onnxruntime: markers 'platform_machine == "aarch64" or platform_machine == "arm64"' don't match your environment
# Collecting numpy<2.0 (from -r requirements.txt (line 2))
#   Using cached numpy-1.26.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting scipy (from -r requirements.txt (line 3))
#   Using cached scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting tensorboard (from -r requirements.txt (line 4))
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting librosa==0.10.2 (from -r requirements.txt (line 5))
#   Using cached librosa-0.10.2-py3-none-any.whl.metadata (8.6 kB)
# Collecting numba (from -r requirements.txt (line 6))
#   Using cached numba-0.60.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting pytorch-lightning>=2.4 (from -r requirements.txt (line 7))
#   Using cached pytorch_lightning-2.6.0-py3-none-any.whl.metadata (21 kB)
# Collecting gradio<5 (from -r requirements.txt (line 8))
#   Using cached gradio-4.44.1-py3-none-any.whl.metadata (15 kB)
# Collecting ffmpeg-python (from -r requirements.txt (line 9))
#   Using cached ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting onnxruntime-gpu (from -r requirements.txt (line 11))
#   Using cached onnxruntime_gpu-1.19.2-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting tqdm (from -r requirements.txt (line 12))
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 2.0 MB/s eta 0:00:00
# Collecting funasr==1.0.27 (from -r requirements.txt (line 13))
#   Using cached funasr-1.0.27-py3-none-any.whl.metadata (26 kB)
# Collecting cn2an (from -r requirements.txt (line 14))
#   Using cached cn2an-0.5.23-py3-none-any.whl.metadata (10 kB)
# Collecting pypinyin (from -r requirements.txt (line 15))
#   Using cached pypinyin-0.55.0-py2.py3-none-any.whl.metadata (12 kB)
# Collecting pyopenjtalk>=0.4.1 (from -r requirements.txt (line 16))
#   Using cached pyopenjtalk-0.4.1-cp39-cp39-linux_x86_64.whl
# Collecting g2p_en (from -r requirements.txt (line 17))
#   Using cached g2p_en-2.1.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting torchaudio (from -r requirements.txt (line 18))
#   Using cached torchaudio-2.8.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (7.2 kB)
# Collecting modelscope (from -r requirements.txt (line 19))
#   Using cached modelscope-1.34.0-py3-none-any.whl.metadata (43 kB)
# Collecting sentencepiece (from -r requirements.txt (line 20))
#   Using cached sentencepiece-0.2.1-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting transformers<=4.50,>=4.43 (from -r requirements.txt (line 21))
#   Using cached transformers-4.50.0-py3-none-any.whl.metadata (39 kB)
# Collecting peft<0.18.0 (from -r requirements.txt (line 22))
#   Using cached peft-0.17.1-py3-none-any.whl.metadata (14 kB)
# Collecting chardet (from -r requirements.txt (line 23))
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting PyYAML (from -r requirements.txt (line 24))
#   Using cached pyyaml-6.0.3-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting psutil (from -r requirements.txt (line 25))
#   Using cached psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting jieba_fast (from -r requirements.txt (line 26))
#   Using cached jieba_fast-0.53-cp39-cp39-linux_x86_64.whl
# Collecting jieba (from -r requirements.txt (line 27))
#   Using cached jieba-0.42.1-py3-none-any.whl
# Collecting split-lang (from -r requirements.txt (line 28))
#   Using cached split_lang-2.1.1-py3-none-any.whl.metadata (86 kB)
# Collecting fast_langdetect>=0.3.1 (from -r requirements.txt (line 29))
#   Using cached fast_langdetect-1.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting wordsegment (from -r requirements.txt (line 30))
#   Using cached wordsegment-1.3.1-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting rotary_embedding_torch (from -r requirements.txt (line 31))
#   Using cached rotary_embedding_torch-0.8.9-py3-none-any.whl.metadata (883 bytes)
# Collecting ToJyutping (from -r requirements.txt (line 32))
#   Using cached ToJyutping-3.2.0-py3-none-any.whl.metadata (25 kB)
# Collecting g2pk2 (from -r requirements.txt (line 33))
#   Using cached g2pk2-0.0.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting ko_pron (from -r requirements.txt (line 34))
#   Using cached ko_pron-1.3-py3-none-any.whl.metadata (2.2 kB)
# Collecting opencc (from -r requirements.txt (line 35))
#   Using cached opencc-1.2.0-cp39-cp39-manylinux2014_x86_64.whl
# Collecting python_mecab_ko (from -r requirements.txt (line 36))
#   Using cached python_mecab_ko-1.3.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting fastapi>=0.115.2 (from fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached fastapi-0.128.8-py3-none-any.whl.metadata (30 kB)
# Collecting x_transformers (from -r requirements.txt (line 38))
#   Using cached x_transformers-2.16.2-py3-none-any.whl.metadata (97 kB)
# Collecting torchmetrics<=1.5 (from -r requirements.txt (line 39))
#   Using cached torchmetrics-1.5.0-py3-none-any.whl.metadata (20 kB)
# Collecting pydantic<=2.10.6 (from -r requirements.txt (line 40))
#   Using cached pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting ctranslate2<5,>=4.0 (from -r requirements.txt (line 41))
#   Using cached ctranslate2-4.7.1-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting av>=11 (from -r requirements.txt (line 42))
#   Using cached av-15.1.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting audioread>=2.1.9 (from librosa==0.10.2->-r requirements.txt (line 5))
#   Using cached audioread-3.1.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting scikit-learn>=0.20.0 (from librosa==0.10.2->-r requirements.txt (line 5))
#   Using cached scikit_learn-1.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting joblib>=0.14 (from librosa==0.10.2->-r requirements.txt (line 5))
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting decorator>=4.3.0 (from librosa==0.10.2->-r requirements.txt (line 5))
#   Using cached decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting soundfile>=0.12.1 (from librosa==0.10.2->-r requirements.txt (line 5))
#   Using cached soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (16 kB)
# Collecting pooch>=1.1 (from librosa==0.10.2->-r requirements.txt (line 5))
#   Using cached pooch-1.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa==0.10.2->-r requirements.txt (line 5))
#   Using cached soxr-1.0.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Collecting typing-extensions>=4.1.1 (from librosa==0.10.2->-r requirements.txt (line 5))
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting lazy-loader>=0.1 (from librosa==0.10.2->-r requirements.txt (line 5))
#   Using cached lazy_loader-0.5-py3-none-any.whl.metadata (5.9 kB)
# Collecting msgpack>=1.0 (from librosa==0.10.2->-r requirements.txt (line 5))
#   Using cached msgpack-1.1.2-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting jamo (from funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached jamo-0.4.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting kaldiio>=2.17.0 (from funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached kaldiio-2.18.1-py3-none-any.whl.metadata (13 kB)
# Collecting torch-complex (from funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached torch_complex-0.4.4-py3-none-any.whl.metadata (3.1 kB)
# Collecting pytorch-wpe (from funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached pytorch_wpe-0.0.1-py3-none-any.whl.metadata (242 bytes)
# Collecting editdistance>=0.5.2 (from funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached editdistance-0.8.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting oss2 (from funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached oss2-2.19.1-py3-none-any.whl
# Collecting umap-learn (from funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached umap_learn-0.5.11-py3-none-any.whl.metadata (26 kB)
# Collecting jaconv (from funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached jaconv-0.5.0-py3-none-any.whl.metadata (8.9 kB)
# Collecting hydra-core>=1.3.2 (from funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting tensorboardX (from funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Collecting openai-whisper (from funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached openai_whisper-20250625-py3-none-any.whl
# Collecting absl-py>=0.4 (from tensorboard->-r requirements.txt (line 4))
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard->-r requirements.txt (line 4))
#   Using cached grpcio-1.78.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.8 kB)
# Collecting markdown>=2.6.8 (from tensorboard->-r requirements.txt (line 4))
#   Using cached markdown-3.9-py3-none-any.whl.metadata (5.1 kB)
# Collecting packaging (from tensorboard->-r requirements.txt (line 4))
#   Using cached packaging-26.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pillow (from tensorboard->-r requirements.txt (line 4))
#   Using cached pillow-11.3.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting protobuf!=4.24.0,>=3.19.6 (from tensorboard->-r requirements.txt (line 4))
#   Using cached protobuf-6.33.5-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting setuptools>=41.0.0 (from tensorboard->-r requirements.txt (line 4))
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->-r requirements.txt (line 4))
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard->-r requirements.txt (line 4))
#   Using cached werkzeug-3.1.6-py3-none-any.whl.metadata (4.0 kB)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba->-r requirements.txt (line 6))
#   Using cached llvmlite-0.43.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting torch>=2.1.0 (from pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached torch-2.8.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting fsspec>=2022.5.0 (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio<5->-r requirements.txt (line 8))
#   Using cached aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Collecting anyio<5.0,>=3.0 (from gradio<5->-r requirements.txt (line 8))
#   Using cached anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting ffmpy (from gradio<5->-r requirements.txt (line 8))
#   Using cached ffmpy-1.0.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.3.0 (from gradio<5->-r requirements.txt (line 8))
#   Using cached gradio_client-1.3.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting httpx>=0.24.1 (from gradio<5->-r requirements.txt (line 8))
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting huggingface-hub>=0.19.3 (from gradio<5->-r requirements.txt (line 8))
#   Using cached huggingface_hub-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting importlib-resources<7.0,>=1.3 (from gradio<5->-r requirements.txt (line 8))
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting jinja2<4.0 (from gradio<5->-r requirements.txt (line 8))
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting markupsafe~=2.0 (from gradio<5->-r requirements.txt (line 8))
#   Using cached MarkupSafe-2.1.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting matplotlib~=3.0 (from gradio<5->-r requirements.txt (line 8))
#   Using cached matplotlib-3.9.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting orjson~=3.0 (from gradio<5->-r requirements.txt (line 8))
#   Using cached orjson-3.11.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting pandas<3.0,>=1.0 (from gradio<5->-r requirements.txt (line 8))
#   Using cached pandas-2.3.3-cp39-cp39-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting pillow (from tensorboard->-r requirements.txt (line 4))
#   Using cached pillow-10.4.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pydub (from gradio<5->-r requirements.txt (line 8))
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio<5->-r requirements.txt (line 8))
#   Using cached python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting ruff>=0.2.2 (from gradio<5->-r requirements.txt (line 8))
#   Using cached ruff-0.15.6-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (26 kB)
# Collecting semantic-version~=2.0 (from gradio<5->-r requirements.txt (line 8))
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio<5->-r requirements.txt (line 8))
#   Using cached tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<1.0,>=0.12 (from gradio<5->-r requirements.txt (line 8))
#   Using cached typer-0.23.2-py3-none-any.whl.metadata (16 kB)
# Collecting urllib3~=2.0 (from gradio<5->-r requirements.txt (line 8))
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting uvicorn>=0.14.0 (from gradio<5->-r requirements.txt (line 8))
#   Using cached uvicorn-0.39.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting websockets<13.0,>=10.0 (from gradio-client==1.3.0->gradio<5->-r requirements.txt (line 8))
#   Using cached websockets-12.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting future (from ffmpeg-python->-r requirements.txt (line 9))
#   Using cached future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting coloredlogs (from onnxruntime-gpu->-r requirements.txt (line 11))
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime-gpu->-r requirements.txt (line 11))
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting sympy (from onnxruntime-gpu->-r requirements.txt (line 11))
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting proces>=0.1.7 (from cn2an->-r requirements.txt (line 14))
#   Using cached proces-0.1.7-py3-none-any.whl.metadata (3.3 kB)
# Collecting nltk>=3.2.4 (from g2p_en->-r requirements.txt (line 17))
#   Using cached nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting inflect>=0.3.1 (from g2p_en->-r requirements.txt (line 17))
#   Using cached inflect-7.5.0-py3-none-any.whl.metadata (24 kB)
# Collecting distance>=0.1.3 (from g2p_en->-r requirements.txt (line 17))
#   Using cached Distance-0.1.3-py3-none-any.whl
# Collecting filelock (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting networkx (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.3 (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.4.0 (from torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached triton-3.4.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting importlib-metadata (from triton==3.4.0->torch>=2.1.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting requests>=2.25 (from modelscope->-r requirements.txt (line 19))
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting huggingface-hub>=0.19.3 (from gradio<5->-r requirements.txt (line 8))
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Collecting regex!=2019.12.17 (from transformers<=4.50,>=4.43->-r requirements.txt (line 21))
#   Using cached regex-2026.1.15-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers<=4.50,>=4.43->-r requirements.txt (line 21))
#   Using cached tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.3 (from transformers<=4.50,>=4.43->-r requirements.txt (line 21))
#   Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting accelerate>=0.21.0 (from peft<0.18.0->-r requirements.txt (line 22))
#   Using cached accelerate-1.10.1-py3-none-any.whl.metadata (19 kB)
# Collecting budoux (from split-lang->-r requirements.txt (line 28))
#   Using cached budoux-0.7.0-py3-none-any.whl.metadata (11 kB)
# Collecting robust-downloader>=0.0.2 (from fast_langdetect>=0.3.1->-r requirements.txt (line 29))
#   Using cached robust_downloader-0.0.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting fasttext-predict>=0.9.2.4 (from fast_langdetect>=0.3.1->-r requirements.txt (line 29))
#   Using cached fasttext_predict-0.9.2.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting einops>=0.7 (from rotary_embedding_torch->-r requirements.txt (line 31))
#   Using cached einops-0.8.2-py3-none-any.whl.metadata (13 kB)
# Collecting python-mecab-ko-dic (from python_mecab_ko->-r requirements.txt (line 36))
#   Using cached python_mecab_ko_dic-2.1.1.post2-py3-none-any.whl.metadata (1.4 kB)
# Collecting starlette<1.0.0,>=0.40.0 (from fastapi>=0.115.2->fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached starlette-0.49.3-py3-none-any.whl.metadata (6.4 kB)
# Collecting typing-inspection>=0.4.2 (from fastapi>=0.115.2->fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi>=0.115.2->fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting einx>=0.3.0 (from x_transformers->-r requirements.txt (line 38))
#   Using cached einx-0.3.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting loguru (from x_transformers->-r requirements.txt (line 38))
#   Using cached loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<=2.10.6->-r requirements.txt (line 40))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<=2.10.6->-r requirements.txt (line 40))
#   Using cached pydantic_core-2.27.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting fastapi-cli>=0.0.8 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached fastapi_cli-0.0.22-py3-none-any.whl.metadata (6.5 kB)
# Collecting email-validator>=2.0.0 (from fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Collecting pydantic-settings>=2.0.0 (from fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached pydantic_settings-2.11.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting pydantic-extra-types>=2.0.0 (from fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached pydantic_extra_types-2.11.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting exceptiongroup>=1.0.2 (from anyio<5.0,>=3.0->gradio<5->-r requirements.txt (line 8))
#   Using cached exceptiongroup-1.3.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting idna>=2.8 (from anyio<5.0,>=3.0->gradio<5->-r requirements.txt (line 8))
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting frozendict (from einx>=0.3.0->x_transformers->-r requirements.txt (line 38))
#   Downloading frozendict-2.4.7-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (23 kB)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting rich-toolkit>=0.14.8 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached rich_toolkit-0.19.7-py3-none-any.whl.metadata (1.0 kB)
# Collecting tomli>=2.0.0 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached tomli-2.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting fastapi-cloud-cli>=0.1.1 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached fastapi_cloud_cli-0.12.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached aiohttp-3.13.3-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting certifi (from httpx>=0.24.1->gradio<5->-r requirements.txt (line 8))
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio<5->-r requirements.txt (line 8))
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.24.1->gradio<5->-r requirements.txt (line 8))
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub>=0.19.3->gradio<5->-r requirements.txt (line 8))
#   Using cached hf_xet-1.4.2-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Collecting omegaconf<2.4,>=2.2 (from hydra-core>=1.3.2->funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.3.2->funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Collecting zipp>=3.1.0 (from importlib-resources<7.0,>=1.3->gradio<5->-r requirements.txt (line 8))
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting more_itertools>=8.5.0 (from inflect>=0.3.1->g2p_en->-r requirements.txt (line 17))
#   Using cached more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Collecting typeguard>=4.0.1 (from inflect>=0.3.1->g2p_en->-r requirements.txt (line 17))
#   Using cached typeguard-4.5.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib~=3.0->gradio<5->-r requirements.txt (line 8))
#   Using cached contourpy-1.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib~=3.0->gradio<5->-r requirements.txt (line 8))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib~=3.0->gradio<5->-r requirements.txt (line 8))
#   Using cached fonttools-4.60.2-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (113 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib~=3.0->gradio<5->-r requirements.txt (line 8))
#   Using cached kiwisolver-1.4.7-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib~=3.0->gradio<5->-r requirements.txt (line 8))
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting python-dateutil>=2.7 (from matplotlib~=3.0->gradio<5->-r requirements.txt (line 8))
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting click (from nltk>=3.2.4->g2p_en->-r requirements.txt (line 17))
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting pytz>=2020.1 (from pandas<3.0,>=1.0->gradio<5->-r requirements.txt (line 8))
#   Using cached pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3.0,>=1.0->gradio<5->-r requirements.txt (line 8))
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting platformdirs>=2.5.0 (from pooch>=1.1->librosa==0.10.2->-r requirements.txt (line 5))
#   Downloading platformdirs-4.4.0-py3-none-any.whl.metadata (12 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings>=2.0.0->fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.25->modelscope->-r requirements.txt (line 19))
#   Downloading charset_normalizer-3.4.5-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (39 kB)
# Collecting colorlog (from robust-downloader>=0.0.2->fast_langdetect>=0.3.1->-r requirements.txt (line 29))
#   Using cached colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=0.20.0->librosa==0.10.2->-r requirements.txt (line 5))
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting cffi>=1.0 (from soundfile>=0.12.1->librosa==0.10.2->-r requirements.txt (line 5))
#   Downloading cffi-2.0.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime-gpu->-r requirements.txt (line 11))
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio<5->-r requirements.txt (line 8))
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer<1.0,>=0.12->gradio<5->-r requirements.txt (line 8))
#   Using cached rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached httptools-0.7.1-cp39-cp39-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (3.5 kB)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached uvloop-0.22.1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached watchfiles-1.1.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu->-r requirements.txt (line 11))
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting tiktoken (from openai-whisper->funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached tiktoken-0.12.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (6.7 kB)
# Collecting crcmod>=1.7 (from oss2->funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached crcmod-1.7-cp39-cp39-linux_x86_64.whl
# Collecting pycryptodome>=3.4.7 (from oss2->funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2->funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2->funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached aliyun_python_sdk_core-2.16.0-py3-none-any.whl
# Collecting six (from oss2->funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting pynndescent>=0.5 (from umap-learn->funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached pynndescent-0.6.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached frozenlist-1.8.0-cp39-cp39-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached multidict-6.7.1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached propcache-0.4.1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.4->-r requirements.txt (line 7))
#   Using cached yarl-1.22.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (75 kB)
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2->funasr==1.0.27->-r requirements.txt (line 13))
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting cryptography>=3.0.0 (from aliyun-python-sdk-core>=2.13.12->oss2->funasr==1.0.27->-r requirements.txt (line 13))
#   Downloading cryptography-46.0.5-cp38-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Collecting pycparser (from cffi>=1.0->soundfile>=0.12.1->librosa==0.10.2->-r requirements.txt (line 5))
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Collecting rignore>=0.5.1 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached rignore-0.7.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting sentry-sdk>=2.20.0 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached sentry_sdk-2.54.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting fastar>=0.8.0 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.2->-r requirements.txt (line 37))
#   Using cached fastar-0.8.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer<1.0,>=0.12->gradio<5->-r requirements.txt (line 8))
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich>=12.3.0->typer<1.0,>=0.12->gradio<5->-r requirements.txt (line 8))
#   Using cached pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio<5->-r requirements.txt (line 8))
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached librosa-0.10.2-py3-none-any.whl (260 kB)
# Using cached funasr-1.0.27-py3-none-any.whl (693 kB)
# Using cached numpy-1.26.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Using cached scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
# Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Using cached numba-0.60.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
# Using cached pytorch_lightning-2.6.0-py3-none-any.whl (849 kB)
# Using cached gradio-4.44.1-py3-none-any.whl (18.1 MB)
# Using cached gradio_client-1.3.0-py3-none-any.whl (318 kB)
# Using cached tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Using cached ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Using cached onnxruntime_gpu-1.19.2-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (226.2 MB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 589.4 kB/s eta 0:00:00
# Using cached cn2an-0.5.23-py3-none-any.whl (224 kB)
# Using cached pypinyin-0.55.0-py2.py3-none-any.whl (840 kB)
# Using cached g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
# Using cached torchaudio-2.8.0-cp39-cp39-manylinux_2_28_x86_64.whl (4.0 MB)
# Using cached torch-2.8.0-cp39-cp39-manylinux_2_28_x86_64.whl (888.0 MB)
# Using cached nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
# Using cached nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
# Using cached nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
# Using cached nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
# Using cached nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
# Using cached nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
# Using cached nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
# Using cached nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
# Using cached nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
# Using cached nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
# Using cached nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.4 MB)
# Using cached nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
# Using cached nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Using cached triton-3.4.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.4 MB)
# Using cached modelscope-1.34.0-py3-none-any.whl (6.1 MB)
# Using cached sentencepiece-0.2.1-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
# Using cached transformers-4.50.0-py3-none-any.whl (10.2 MB)
# Using cached peft-0.17.1-py3-none-any.whl (504 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached pyyaml-6.0.3-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (750 kB)
# Using cached psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (155 kB)
# Using cached split_lang-2.1.1-py3-none-any.whl (32 kB)
# Using cached fast_langdetect-1.0.0-py3-none-any.whl (789 kB)
# Using cached wordsegment-1.3.1-py2.py3-none-any.whl (4.8 MB)
# Using cached rotary_embedding_torch-0.8.9-py3-none-any.whl (5.9 kB)
# Using cached ToJyutping-3.2.0-py3-none-any.whl (287 kB)
# Using cached g2pk2-0.0.3-py3-none-any.whl (25 kB)
# Using cached ko_pron-1.3-py3-none-any.whl (12 kB)
# Using cached python_mecab_ko-1.3.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578 kB)
# Using cached fastapi-0.128.8-py3-none-any.whl (103 kB)
# Using cached x_transformers-2.16.2-py3-none-any.whl (102 kB)
# Using cached torchmetrics-1.5.0-py3-none-any.whl (890 kB)
# Using cached pydantic-2.10.6-py3-none-any.whl (431 kB)
# Using cached pydantic_core-2.27.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Using cached ctranslate2-4.7.1-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (38.6 MB)
# Using cached av-15.1.0-cp39-cp39-manylinux_2_28_x86_64.whl (39.1 MB)
# Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Using cached accelerate-1.10.1-py3-none-any.whl (374 kB)
# Using cached aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached anyio-4.12.1-py3-none-any.whl (113 kB)
# Using cached audioread-3.1.0-py3-none-any.whl (23 kB)
# Using cached decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Using cached editdistance-0.8.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (401 kB)
# Using cached einops-0.8.2-py3-none-any.whl (65 kB)
# Using cached einx-0.3.0-py3-none-any.whl (102 kB)
# Using cached email_validator-2.3.0-py3-none-any.whl (35 kB)
# Using cached fastapi_cli-0.0.22-py3-none-any.whl (12 kB)
# Using cached fasttext_predict-0.9.2.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
# Using cached fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Using cached grpcio-1.78.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.7 MB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached inflect-7.5.0-py3-none-any.whl (35 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached kaldiio-2.18.1-py3-none-any.whl (29 kB)
# Using cached lazy_loader-0.5-py3-none-any.whl (8.0 kB)
# Using cached lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Using cached llvmlite-0.43.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
# Using cached markdown-3.9-py3-none-any.whl (107 kB)
# Using cached MarkupSafe-2.1.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Using cached matplotlib-3.9.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Using cached msgpack-1.1.2-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (404 kB)
# Using cached nltk-3.9.2-py3-none-any.whl (1.5 MB)
# Using cached orjson-3.11.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
# Using cached packaging-26.0-py3-none-any.whl (74 kB)
# Using cached pandas-2.3.3-cp39-cp39-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
# Using cached pillow-10.4.0-cp39-cp39-manylinux_2_28_x86_64.whl (4.5 MB)
# Using cached pooch-1.9.0-py3-none-any.whl (67 kB)
# Using cached proces-0.1.7-py3-none-any.whl (137 kB)
# Using cached protobuf-6.33.5-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
# Using cached pydantic_extra_types-2.11.0-py3-none-any.whl (74 kB)
# Using cached pydantic_settings-2.11.0-py3-none-any.whl (48 kB)
# Using cached python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Using cached regex-2026.1.15-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (791 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached robust_downloader-0.0.2-py3-none-any.whl (15 kB)
# Using cached ruff-0.15.6-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
# Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Using cached scikit_learn-1.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
# Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Using cached setuptools-82.0.1-py3-none-any.whl (1.0 MB)
# Using cached soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl (1.3 MB)
# Using cached soxr-1.0.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (242 kB)
# Using cached starlette-0.49.3-py3-none-any.whl (74 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# Using cached tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Using cached typer-0.23.2-py3-none-any.whl (56 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached uvicorn-0.39.0-py3-none-any.whl (68 kB)
# Using cached werkzeug-3.1.6-py3-none-any.whl (225 kB)
# Using cached budoux-0.7.0-py3-none-any.whl (118 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached ffmpy-1.0.0-py3-none-any.whl (5.6 kB)
# Using cached filelock-3.19.1-py3-none-any.whl (15 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached future-1.0.0-py3-none-any.whl (491 kB)
# Using cached jaconv-0.5.0-py3-none-any.whl (16 kB)
# Using cached jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Using cached loguru-0.7.3-py3-none-any.whl (61 kB)
# Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Using cached python_mecab_ko_dic-2.1.1.post2-py3-none-any.whl (34.5 MB)
# Using cached pytorch_wpe-0.0.1-py3-none-any.whl (8.1 kB)
# Using cached tensorboardx-2.6.4-py3-none-any.whl (87 kB)
# Using cached torch_complex-0.4.4-py3-none-any.whl (9.1 kB)
# Using cached umap_learn-0.5.11-py3-none-any.whl (90 kB)
# Using cached aiohttp-3.13.3-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
# Using cached aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl (99 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.7/153.7 kB 656.1 kB/s eta 0:00:00
# Downloading cffi-2.0.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 kB 14.9 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.5-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.6/196.6 kB 13.3 MB/s eta 0:00:00
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached contourpy-1.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (321 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached dnspython-2.7.0-py3-none-any.whl (313 kB)
# Using cached exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Using cached fastapi_cloud_cli-0.12.0-py3-none-any.whl (27 kB)
# Using cached fonttools-4.60.2-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.8 MB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached hf_xet-1.4.2-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.2 MB)
# Using cached httptools-0.7.1-cp39-cp39-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (441 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 5.5 MB/s eta 0:00:00
# Using cached importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Using cached kiwisolver-1.4.7-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Using cached more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Downloading platformdirs-4.4.0-py3-none-any.whl (18 kB)
# Using cached pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
# Using cached pynndescent-0.6.0-py3-none-any.whl (73 kB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Using cached rich-14.3.3-py3-none-any.whl (310 kB)
# Using cached rich_toolkit-0.19.7-py3-none-any.whl (32 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tomli-2.4.0-py3-none-any.whl (14 kB)
# Using cached typeguard-4.5.1-py3-none-any.whl (36 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Using cached uvloop-0.22.1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.7 MB)
# Using cached watchfiles-1.1.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (457 kB)
# Using cached websockets-12.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Using cached colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading frozendict-2.4.7-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.6/119.6 kB 9.0 MB/s eta 0:00:00
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Using cached tiktoken-0.12.0-cp39-cp39-manylinux_2_28_x86_64.whl (1.2 MB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading cryptography-46.0.5-cp38-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 59.0 MB/s eta 0:00:00
# Using cached fastar-0.8.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (821 kB)
# Using cached frozenlist-1.8.0-cp39-cp39-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (219 kB)
# Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached multidict-6.7.1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (240 kB)
# Using cached propcache-0.4.1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (197 kB)
# Using cached pygments-2.19.2-py3-none-any.whl (1.2 MB)
# Using cached rignore-0.7.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (961 kB)
# Using cached sentry_sdk-2.54.0-py2.py3-none-any.whl (439 kB)
# Using cached yarl-1.22.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (346 kB)
# Downloading pycparser-2.23-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 8.9 MB/s eta 0:00:00
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: wordsegment, pytz, python-mecab-ko-dic, pydub, opencc, nvidia-cusparselt-cu12, mpmath, ko_pron, jieba_fast, jieba, jamo, jaconv, flatbuffers, fasttext-predict, distance, crcmod, antlr4-python3-runtime, zipp, websockets, uvloop, urllib3, tzdata, typing-extensions, tqdm, tomlkit, tomli, ToJyutping, threadpoolctl, tensorboard-data-server, sympy, six, shellingham, setuptools, sentencepiece, semantic-version, safetensors, ruff, rignore, regex, PyYAML, python-multipart, python_mecab_ko, python-dotenv, pypinyin, pyparsing, pygments, pycryptodome, pycparser, psutil, protobuf, propcache, proces, platformdirs, pillow, packaging, orjson, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, msgpack, more_itertools, mdurl, markupsafe, loguru, llvmlite, kiwisolver, joblib, jmespath, idna, humanfriendly, httptools, hf-xet, h11, future, fsspec, frozenlist, frozendict, fonttools, filelock, ffmpy, fastar, einops, editdistance, dnspython, decorator, cycler, colorlog, click, charset_normalizer, chardet, certifi, av, audioread, attrs, async-timeout, annotated-types, annotated-doc, aiohappyeyeballs, aiofiles, absl-py, werkzeug, uvicorn, typing-inspection, torch-complex, tensorboardX, soxr, sentry-sdk, scipy, requests, pytorch-wpe, python-dateutil, pyopenjtalk, pydantic-core, omegaconf, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, numba, nltk, multidict, markdown-it-py, lightning-utilities, lazy-loader, kaldiio, jinja2, importlib-resources, importlib-metadata, httpcore, grpcio, ffmpeg-python, exceptiongroup, email-validator, einx, ctranslate2, contourpy, coloredlogs, cn2an, cffi, aiosignal, yarl, typeguard, triton, tiktoken, soundfile, scikit-learn, robust-downloader, rich, pydantic, pooch, pandas, onnxruntime-gpu, nvidia-cusolver-cu12, modelscope, matplotlib, markdown, hydra-core, huggingface-hub, g2pk2, cryptography, budoux, anyio, watchfiles, typer, torch, tokenizers, tensorboard, starlette, rich-toolkit, pynndescent, pydantic-settings, pydantic-extra-types, librosa, inflect, httpx, fast_langdetect, aliyun-python-sdk-core, aiohttp, x_transformers, umap-learn, transformers, torchmetrics, torchaudio, split-lang, rotary_embedding_torch, openai-whisper, gradio-client, g2p_en, fastapi, aliyun-python-sdk-kms, accelerate, pytorch-lightning, peft, oss2, gradio, fastapi-cloud-cli, fastapi-cli, funasr
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyopenssl 23.2.0 requires cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0, but you have cryptography 46.0.5 which is incompatible.
# Successfully installed PyYAML-6.0.3 ToJyutping-3.2.0 absl-py-2.3.1 accelerate-1.10.1 aiofiles-23.2.1 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 aliyun-python-sdk-core-2.16.0 aliyun-python-sdk-kms-2.16.5 annotated-doc-0.0.4 annotated-types-0.7.0 antlr4-python3-runtime-4.9.3 anyio-4.12.1 async-timeout-5.0.1 attrs-25.4.0 audioread-3.1.0 av-15.1.0 budoux-0.7.0 certifi-2026.2.25 cffi-2.0.0 chardet-5.2.0 charset_normalizer-3.4.5 click-8.1.8 cn2an-0.5.23 coloredlogs-15.0.1 colorlog-6.10.1 contourpy-1.3.0 crcmod-1.7 cryptography-46.0.5 ctranslate2-4.7.1 cycler-0.12.1 decorator-5.2.1 distance-0.1.3 dnspython-2.7.0 editdistance-0.8.1 einops-0.8.2 einx-0.3.0 email-validator-2.3.0 exceptiongroup-1.3.1 fast_langdetect-1.0.0 fastapi-0.128.8 fastapi-cli-0.0.22 fastapi-cloud-cli-0.12.0 fastar-0.8.0 fasttext-predict-0.9.2.4 ffmpeg-python-0.2.0 ffmpy-1.0.0 filelock-3.19.1 flatbuffers-25.12.19 fonttools-4.60.2 frozendict-2.4.7 frozenlist-1.8.0 fsspec-2025.10.0 funasr-1.0.27 future-1.0.0 g2p_en-2.1.0 g2pk2-0.0.3 gradio-4.44.1 gradio-client-1.3.0 grpcio-1.78.0 h11-0.16.0 hf-xet-1.4.2 httpcore-1.0.9 httptools-0.7.1 httpx-0.28.1 huggingface-hub-0.36.2 humanfriendly-10.0 hydra-core-1.3.2 idna-3.11 importlib-metadata-8.7.1 importlib-resources-6.5.2 inflect-7.5.0 jaconv-0.5.0 jamo-0.4.1 jieba-0.42.1 jieba_fast-0.53 jinja2-3.1.6 jmespath-0.10.0 joblib-1.5.3 kaldiio-2.18.1 kiwisolver-1.4.7 ko_pron-1.3 lazy-loader-0.5 librosa-0.10.2 lightning-utilities-0.15.2 llvmlite-0.43.0 loguru-0.7.3 markdown-3.9 markdown-it-py-3.0.0 markupsafe-2.1.5 matplotlib-3.9.4 mdurl-0.1.2 modelscope-1.34.0 more_itertools-10.8.0 mpmath-1.3.0 msgpack-1.1.2 multidict-6.7.1 networkx-3.2.1 nltk-3.9.2 numba-0.60.0 numpy-1.26.4 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.3 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvtx-cu12-12.8.90 omegaconf-2.3.0 onnxruntime-gpu-1.19.2 openai-whisper-20250625 opencc-1.2.0 orjson-3.11.5 oss2-2.19.1 packaging-26.0 pandas-2.3.3 peft-0.17.1 pillow-10.4.0 platformdirs-4.4.0 pooch-1.9.0 proces-0.1.7 propcache-0.4.1 protobuf-6.33.5 psutil-7.2.2 pycparser-2.23 pycryptodome-3.23.0 pydantic-2.10.6 pydantic-core-2.27.2 pydantic-extra-types-2.11.0 pydantic-settings-2.11.0 pydub-0.25.1 pygments-2.19.2 pynndescent-0.6.0 pyopenjtalk-0.4.1 pyparsing-3.3.2 pypinyin-0.55.0 python-dateutil-2.9.0.post0 python-dotenv-1.2.1 python-mecab-ko-dic-2.1.1.post2 python-multipart-0.0.20 python_mecab_ko-1.3.7 pytorch-lightning-2.6.0 pytorch-wpe-0.0.1 pytz-2026.1.post1 regex-2026.1.15 requests-2.32.5 rich-14.3.3 rich-toolkit-0.19.7 rignore-0.7.6 robust-downloader-0.0.2 rotary_embedding_torch-0.8.9 ruff-0.15.6 safetensors-0.7.0 scikit-learn-1.6.1 scipy-1.13.1 semantic-version-2.10.0 sentencepiece-0.2.1 sentry-sdk-2.54.0 setuptools-82.0.1 shellingham-1.5.4 six-1.17.0 soundfile-0.13.1 soxr-1.0.0 split-lang-2.1.1 starlette-0.49.3 sympy-1.14.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorboardX-2.6.4 threadpoolctl-3.6.0 tiktoken-0.12.0 tokenizers-0.21.4 tomli-2.4.0 tomlkit-0.12.0 torch-2.8.0 torch-complex-0.4.4 torchaudio-2.8.0 torchmetrics-1.5.0 tqdm-4.67.3 transformers-4.50.0 triton-3.4.0 typeguard-4.5.1 typer-0.23.2 typing-extensions-4.15.0 typing-inspection-0.4.2 tzdata-2025.3 umap-learn-0.5.11 urllib3-2.6.3 uvicorn-0.39.0 uvloop-0.22.1 watchfiles-1.1.1 websockets-12.0 werkzeug-3.1.6 wordsegment-1.3.1 x_transformers-2.16.2 yarl-1.22.0 zipp-3.23.0

# %%
#@title STEP1.2 下载预训练模型 (≈2min)
#@markdown Download pretrained models (≈2min)
# !mkdir -p /content/GPT-SoVITS/GPT_SoVITS/pretrained_models
# !mkdir -p /content/GPT-SoVITS/tools/damo_asr/models
# !mkdir -p /content/GPT-SoVITS/tools/uvr5
# %cd /content/GPT-SoVITS/GPT_SoVITS/pretrained_models
# !git clone https://huggingface.co/lj1995/GPT-SoVITS
# %cd /content/GPT-SoVITS/tools/damo_asr/models
# !git clone https://www.modelscope.cn/damo/speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch.git
# !git clone https://www.modelscope.cn/damo/speech_fsmn_vad_zh-cn-16k-common-pytorch.git
# !git clone https://www.modelscope.cn/damo/punc_ct-transformer_zh-cn-common-vocab272727-pytorch.git
# %cd /content/GPT-SoVITS/tools/uvr5
# !git clone https://huggingface.co/Delik/uvr5_weights
# !git config core.sparseCheckout true
# !mv /content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/* /content/GPT-SoVITS/GPT_SoVITS/pretrained_models/
# Out:
# /content/GPT-SoVITS/GPT_SoVITS/pretrained_models
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 69 (delta 12), reused 0 (delta 0), pack-reused 4 (from 1)
# Receiving objects: 100% (69/69), 115.94 KiB | 4.83 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# Filtering content: 100% (19/19), 4.93 GiB | 19.75 MiB/s, done.
# /content/GPT-SoVITS/tools/damo_asr/models
# Cloning into 'speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch'...
# remote: Enumerating objects: 466, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (38/38), done.
# error: RPC failed; curl 18 transfer closed with outstanding read data remaining
# error: 3378 bytes of body are still expected
# fetch-pack: unexpected disconnect while reading sideband packet
# fatal: early EOF
# fatal: fetch-pack: invalid index-pack output
# Cloning into 'speech_fsmn_vad_zh-cn-16k-common-pytorch'...
# remote: Enumerating objects: 184, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 184 (delta 18), reused 23 (delta 10), pack-reused 145
# Receiving objects: 100% (184/184), 4.66 MiB | 4.94 MiB/s, done.
# Resolving deltas: 100% (91/91), done.
# Cloning into 'punc_ct-transformer_zh-cn-common-vocab272727-pytorch'...
# remote: Enumerating objects: 174, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (30/30), done.
# error: RPC failed; curl 18 transfer closed with outstanding read data remaining
# error: 3774 bytes of body are still expected
# fetch-pack: unexpected disconnect while reading sideband packet
# fatal: early EOF
# fatal: fetch-pack: invalid index-pack output
# /content/GPT-SoVITS/tools/uvr5
# fatal: destination path 'uvr5_weights' already exists and is not an empty directory.

# %% [markdown]
# ---
#
# #### Part2:模型训练 Model training
#
# ---

# %%
#@title WebUI！！ 启动！！！
#@markdown launch WebUI
# !/usr/local/bin/pip install ipykernel
# Force set is_share to True on line 10 of config.py
# !sed -i '10s/.*/is_share = True/' /content/GPT-SoVITS/config.py
# Verify the change
# !echo "--- content of config.py after modification ---"
# !head -n 10 /content/GPT-SoVITS/config.py
# !echo "----------------------------------------------"
# %cd /content/GPT-SoVITS/
# !/usr/local/bin/python  webui.py
# Out:
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.9/site-packages (6.31.0)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.9/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.9/site-packages (from ipykernel) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.9/site-packages (from ipykernel) (8.18.1)
# Requirement already satisfied: jupyter-client>=8.0.0 in /usr/local/lib/python3.9/site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.9/site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.9/site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /usr/local/lib/python3.9/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in /usr/local/lib/python3.9/site-packages (from ipykernel) (23.1)
# Requirement already satisfied: psutil>=5.7 in /usr/local/lib/python3.9/site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /usr/local/lib/python3.9/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.9/site-packages (from ipykernel) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.9/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (4.15.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (1.3.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /usr/local/lib/python3.9/site-packages (from jupyter-client>=8.0.0->ipykernel) (8.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.9/site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (3.10.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=8.0.0->ipykernel) (3.23.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.3)
# --- content of config.py after modification ---
# import os
# import re
# import sys
#
# import torch
#
# from tools.i18n.i18n import I18nAuto
#
# i18n = I18nAuto(language=os.environ.get("language", "Auto"))
#
# ----------------------------------------------
# /content/GPT-SoVITS
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://f190a8d5082d27284d.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# "/usr/local/bin/python" -s GPT_SoVITS/inference_webui.py "Auto"
# GPT_SoVITS/pretrained_models/gsv-v2final-pretrained/s2G2333k.pth v2 v2 False
# loading sovits_v2 <All keys matched successfully>
# Running on local URL:  http://0.0.0.0:9872
# Running on public URL: https://d7f3a576f43882a9fa.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Actual Input Reference Text: 这是一段测试音频，我的名字叫易涌涛。
# Actual Input Target Text: 收到
# Actual Input Target Text (after sentence segmentation): 收到
# ['这是一段测试音频，我的名字叫易涌涛。']
# ['zh']
# Segmentation fault (core dumped)
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/gradio/blocks.py", line 2709, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/GPT-SoVITS/webui.py", line 1975, in <module>
#     app.queue().launch(  # concurrency_count=511, max_size=1022
#   File "/usr/local/lib/python3.9/site-packages/gradio/blocks.py", line 2614, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.9/site-packages/gradio/blocks.py", line 2713, in block_thread
#     self.server.close()
#   File "/usr/local/lib/python3.9/site-packages/gradio/http_server.py", line 68, in close
#     self.thread.join(timeout=5)
#   File "/usr/local/lib/python3.9/threading.py", line 1064, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/usr/local/lib/python3.9/threading.py", line 1080, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
# Killing tunnel 0.0.0.0:9874 <> https://f190a8d5082d27284d.gradio.live
# ^C

# %% [markdown]
# ---
#
# #### Part3:模型文件备份 Model backup (Google Drive)
#
# ---

# %%
#@title 备份模型到Google Drive
#@markdown Back up model files to Google Drive

modlename = input("请输入要保存的模型目录名称 Please enter the role name for this training：")

# 创建模型输出目录
# !mkdir -p /content/drive/MyDrive/GPT_SoVITS/{modlename}/Model_output/GPT_weights
# !mkdir -p /content/drive/MyDrive/GPT_SoVITS/{modlename}/Model_output/SoVITS_weights
print("模型输出目录创建成功！\nThe model output directory is created successfully!")
# 备份模型文件
# !cp /content/GPT-SoVITS/GPT_weights/* /content/drive/MyDrive/GPT_SoVITS/{modlename}/Model_output/GPT_weights
# !cp /content/GPT-SoVITS/SoVITS_weights/* /content/drive/MyDrive/GPT_SoVITS/{modlename}/Model_output/SoVITS_weights
print("备份成功！Google Drive更新可能有延迟，请多刷新")
print("Backup successful! Google Drive update may be delayed, please refresh frequently.")
print("-------------------------------------")
print("请检查GPT_SoVITS/%s/Model_output/GPT_weights目录下是否存在模型文件！ " % modlename)
print("请检查GPT_SoVITS/%s/Model_output/SoVITS_weights目录下是否存在模型文件！ " % modlename)
print("Please Check GPT_SoVITS/%s/Model_output/GPT_weights " % modlename)
print("Please Check GPT_SoVITS/%s/Model_output/SoVITS_weights " % modlename)
print("Google Drive：https://drive.google.com/drive/my-drive")

# %%
#@title 备份音频切片和标记文件到Google Drive
#@markdown Back up audio slices and tagged files to Google Drive
modlename = input("请输入要保存的模型目录名称 Please enter the role name for this training：")
# !mkdir -p /content/drive/MyDrive/GPT_SoVITS/{modlename}/Audio_output/asr_opt
# !mkdir -p /content/drive/MyDrive/GPT_SoVITS/{modlename}/Audio_output/slicer_opt
print("模型输出目录创建成功！\nThe model output directory is created successfully!")
# !cp /content/GPT-SoVITS/output/asr_opt/* /content/drive/MyDrive/GPT_SoVITS/{modlename}/Audio_output/asr_opt
# !cp /content/GPT-SoVITS/output/slicer_opt/* /content/drive/MyDrive/GPT_SoVITS/{modlename}/Audio_output/slicer_opt
print("备份成功！Google Drive更新可能有延迟，请多刷新")
print("Backup successful! Google Drive update may be delayed, please refresh frequently.")
print("-------------------------------------")
print("请检查GPT_SoVITS/%s/Audio_output/asr_opt目录下是否存在音频切片文件！ " % modlename)
print("请检查GPT_SoVITS/%s/Audio_output/slicer_opt目录下是否存在.list标记文件！ " % modlename)
print("Please Check GPT_SoVITS/%s/Audio_output/asr_opt " % modlename)
print("Please Check GPT_SoVITS/%s/Audio_output/slicer_opt " % modlename)
print("Google Drive：https://drive.google.com/drive/my-drive")

# %%
import os
from google.colab import drive
drive.mount('/content/drive')

# 在云盘创建一个专门存 Python 库的文件夹
# !mkdir -p /content/drive/MyDrive/colab_env/gpt_sovits_lib
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 备份所有预训练模型（推理必须的基础文件）
# !mkdir -p /content/drive/MyDrive/GPT_SoVITS/Pretrained_Models
# !cp -rv /content/GPT-SoVITS/GPT_SoVITS/pretrained_models/* /content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/
# Out:
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/chinese-hubert-base/config.json' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/chinese-hubert-base/config.json'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/chinese-hubert-base/preprocessor_config.json' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/chinese-hubert-base/preprocessor_config.json'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/chinese-hubert-base/pytorch_model.bin' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/chinese-hubert-base/pytorch_model.bin'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large/config.json' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/chinese-roberta-wwm-ext-large/config.json'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large/tokenizer.json' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/chinese-roberta-wwm-ext-large/tokenizer.json'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large/pytorch_model.bin' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/chinese-roberta-wwm-ext-large/pytorch_model.bin'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/fast_langdetect/lid.176.bin' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/fast_langdetect/lid.176.bin'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/info/exclude' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/info/exclude'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/description' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/description'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/pre-push.sample' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/pre-push.sample'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/commit-msg.sample' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/commit-msg.sample'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/pre-merge-commit.sample' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/pre-merge-commit.sample'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/pre-receive.sample' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/pre-receive.sample'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/pre-applypatch.sample' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/pre-applypatch.sample'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/push-to-checkout.sample' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/push-to-checkout.sample'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/update.sample' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/update.sample'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/fsmonitor-watchman.sample' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/fsmonitor-watchman.sample'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/prepare-commit-msg.sample' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/prepare-commit-msg.sample'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/applypatch-msg.sample' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/applypatch-msg.sample'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/pre-rebase.sample' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/pre-rebase.sample'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/post-update.sample' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/post-update.sample'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/pre-commit.sample' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/pre-commit.sample'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/pre-push' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/pre-push'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/post-checkout' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/post-checkout'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/post-commit' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/post-commit'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/hooks/post-merge' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/hooks/post-merge'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/refs/heads/main' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/refs/heads/main'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/refs/remotes/origin/HEAD' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/refs/remotes/origin/HEAD'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/index' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/index'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/objects/pack/pack-737bb2036c0a852399135079a6f7f29dd35822bd.pack' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/objects/pack/pack-737bb2036c0a852399135079a6f7f29dd35822bd.pack'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/objects/pack/pack-737bb2036c0a852399135079a6f7f29dd35822bd.idx' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/objects/pack/pack-737bb2036c0a852399135079a6f7f29dd35822bd.idx'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/packed-refs' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/packed-refs'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/logs/refs/remotes/origin/HEAD' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/logs/refs/remotes/origin/HEAD'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/logs/refs/heads/main' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/logs/refs/heads/main'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/logs/HEAD' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/logs/HEAD'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/HEAD' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/HEAD'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/config' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/config'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/24/16/24164f129c66499d1346e2aa55f183250c223161ec2770c0da3d3b08cf432d3c' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/24/16/24164f129c66499d1346e2aa55f183250c223161ec2770c0da3d3b08cf432d3c'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/e5/3a/e53a693acc59ace251d143d068096ae0d7b79e4b1b503fa84c9dcf576448c1d8' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/e5/3a/e53a693acc59ace251d143d068096ae0d7b79e4b1b503fa84c9dcf576448c1d8'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/73/2f/732f94e63b148066e24c7f9d2637f3374083e637635f07fbdb695dee20ddbe1f' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/73/2f/732f94e63b148066e24c7f9d2637f3374083e637635f07fbdb695dee20ddbe1f'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/8a/e7/8ae7fe8dd8c8f2e718de359e00edac88b0c71ab2fd10b07ad4cc45070eb8a836' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/8a/e7/8ae7fe8dd8c8f2e718de359e00edac88b0c71ab2fd10b07ad4cc45070eb8a836'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/92/4f/924fdccaa3c574bf139c25c9759aa1ed3b3f99e19a7c529ee996c2bc17663695' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/92/4f/924fdccaa3c574bf139c25c9759aa1ed3b3f99e19a7c529ee996c2bc17663695'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/90/6f/906fe22f48c3e037a389df291d4d32a9414e15dbb8f9628643e83aaced109ea4' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/90/6f/906fe22f48c3e037a389df291d4d32a9414e15dbb8f9628643e83aaced109ea4'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/4d/61/4d611913df7b12d49e8976c944558d2d096816365edfc6c35a9e85b67dd14ed9' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/4d/61/4d611913df7b12d49e8976c944558d2d096816365edfc6c35a9e85b67dd14ed9'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/41/cd/41cddf71b72adf154fb973afafed6208bfd74920c9394f44c78bf4c73077bea3' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/41/cd/41cddf71b72adf154fb973afafed6208bfd74920c9394f44c78bf4c73077bea3'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/6f/9c/6f9c5715550c9d0f11159ceb8935638da5aeb19e27d1e63677632df095e376f5' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/6f/9c/6f9c5715550c9d0f11159ceb8935638da5aeb19e27d1e63677632df095e376f5'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/b1/c1/b1c1e17e9c99547a89388f72048cd6e1b41b5a18b170e86a46dfde0324d63eb1' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/b1/c1/b1c1e17e9c99547a89388f72048cd6e1b41b5a18b170e86a46dfde0324d63eb1'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/87/13/87133414860ea14ff6620c483a3db5ed07b44be42e2c3fcdad65523a729a745a' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/87/13/87133414860ea14ff6620c483a3db5ed07b44be42e2c3fcdad65523a729a745a'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/fc/57/fc579c1db3c1e21b721001cf99d7a584214280df19b002e200b630a34fa06eb8' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/fc/57/fc579c1db3c1e21b721001cf99d7a584214280df19b002e200b630a34fa06eb8'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/02/0a/020a014e1e01e550e510f2f61fae5e5f5b6aab40f15c22f1f12f724df507e835' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/02/0a/020a014e1e01e550e510f2f61fae5e5f5b6aab40f15c22f1f12f724df507e835'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/f3/3a/f33abb1920076d988e1711d5f41b5c9c6d7f92575b4acf0ad4fae6a4ebf0cf19' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/f3/3a/f33abb1920076d988e1711d5f41b5c9c6d7f92575b4acf0ad4fae6a4ebf0cf19'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/4f/5a/4f5a0bf73c61eb41b174e1bb54e7ee3c83233892be8e0af1f187024e8e581a35' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/4f/5a/4f5a0bf73c61eb41b174e1bb54e7ee3c83233892be8e0af1f187024e8e581a35'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/25/7a/257a7f36ae49e9ff08790d2cd3d398592530852caba810197f8606e884a52c54' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/25/7a/257a7f36ae49e9ff08790d2cd3d398592530852caba810197f8606e884a52c54'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/63/5c/635cd84bf6f7f9b8d41c88c7106f81d782c794c61f931845214ea037b0c5bef2' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/63/5c/635cd84bf6f7f9b8d41c88c7106f81d782c794c61f931845214ea037b0c5bef2'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/0f/8e/0f8ead815234365edf045c6d86370ed6e4f440e8195be77ff0ea72684ad406a5' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/0f/8e/0f8ead815234365edf045c6d86370ed6e4f440e8195be77ff0ea72684ad406a5'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.git/lfs/objects/d4/2a/d42a22bbbf65fb2bbdd45ad6a66841156977db45c7aabe0a6992ff378d9c7d3b' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.git/lfs/objects/d4/2a/d42a22bbbf65fb2bbdd45ad6a66841156977db45c7aabe0a6992ff378d9c7d3b'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/.gitattributes' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/GPT-SoVITS/.gitattributes'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/gsv-v2final-pretrained/s1bert25hz-5kh-longer-epoch=12-step=369668.ckpt' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/gsv-v2final-pretrained/s1bert25hz-5kh-longer-epoch=12-step=369668.ckpt'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/gsv-v2final-pretrained/s2D2333k.pth' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/gsv-v2final-pretrained/s2D2333k.pth'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/gsv-v2final-pretrained/s2G2333k.pth' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/gsv-v2final-pretrained/s2G2333k.pth'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/gsv-v4-pretrained/vocoder.pth' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/gsv-v4-pretrained/vocoder.pth'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/gsv-v4-pretrained/s2Gv4.pth' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/gsv-v4-pretrained/s2Gv4.pth'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/hifigan_config.json' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/hifigan_config.json'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/hifigan_do_03357000' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/hifigan_do_03357000'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/models--nvidia--bigvgan_v2_24khz_100band_256x/config.json' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/models--nvidia--bigvgan_v2_24khz_100band_256x/config.json'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/models--nvidia--bigvgan_v2_24khz_100band_256x/bigvgan_generator.pt' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/models--nvidia--bigvgan_v2_24khz_100band_256x/bigvgan_generator.pt'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/README.md' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/README.md'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/s1bert25hz-2kh-longer-epoch=68e-step=50232.ckpt' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/s1bert25hz-2kh-longer-epoch=68e-step=50232.ckpt'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/s1v3.ckpt' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/s1v3.ckpt'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/s2D488k.pth' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/s2D488k.pth'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/s2G488k.pth' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/s2G488k.pth'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/s2Gv3.pth' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/s2Gv3.pth'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/sv/pretrained_eres2netv2w24s4ep4.ckpt' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/sv/pretrained_eres2netv2w24s4ep4.ckpt'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/v2Pro/s2Gv2Pro.pth' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/v2Pro/s2Gv2Pro.pth'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/v2Pro/s2Gv2ProPlus.pth' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/v2Pro/s2Gv2ProPlus.pth'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/v2Pro/s2Dv2ProPlus.pth' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/v2Pro/s2Dv2ProPlus.pth'
# '/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/v2Pro/s2Dv2Pro.pth' -> '/content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/v2Pro/s2Dv2Pro.pth'

# %%
# 1. 挂载云盘
from google.colab import drive
import sys
drive.mount('/content/drive')

# 2. 这里的路径必须指向你今天备份环境的地方
sys.path.insert(0, '/content/drive/MyDrive/colab_env/gpt_sovits_lib')

# 3. 必须重新安装 Conda 环境 (这步省不掉，大约 3-5 分钟)
# !pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/miniconda/Miniconda3-py39_23.11.0-2-Linux-x86_64.sh")

# 4. 克隆代码并安装系统级依赖
# %cd -q /content
# !git clone https://github.com/RVC-Boss/GPT-SoVITS
# %cd -q /content/GPT-SoVITS
# !conda install -y -q -c conda-forge gcc gxx ffmpeg cmake -c pytorch -c nvidia cudatoolkit

# 5. 把模型拷回来 (假设你今天已经备份到了 Pretrained_Models)
# !cp -rv /content/drive/MyDrive/GPT_SoVITS/Pretrained_Models/* /content/GPT-SoVITS/GPT_SoVITS/pretrained_models/

print("✅ 环境注入成功！现在可以直接跳过 Step 1.1 的 pip 安装，直接去启动 WebUI 了。")
